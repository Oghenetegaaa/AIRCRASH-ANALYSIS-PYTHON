# %%
import pandas as pd
import seaborn as sns
import statistics as st
import matplotlib.pyplot as mlt

# %%
df = pd.read_csv("aircrahesFullDataUpdated_2024 (1).csv")

# %%
df.shape
# Out:
# (5035, 12)

# %%
df.head(5)
# Out:
#    Year Quarter  Month  Day Country/Region Aircraft Manufacturer  \
# 0  1970   Qtr 2  April   28            NaN   de Havilland Canada
# 1  1952   Qtr 2  April   30            NaN               Douglas
# 2  1973   Qtr 2  April   10            NaN      Vickers Vanguard
# 3  2000   Qtr 2  April   19             '-               Antonov
# 4  1946   Qtr 2  April   30             '-               Douglas
#
#                                      Aircraft       Location  \
# 0  de Havilland Canada DHC 6 Twin Otter 100VH        Kainatu
# 1                              Douglas DC 3VT          Delhi
# 2                  Vickers Vanguard 952G AXOP     Near Basel
# 3                              Antonov AN 8TL        Pepa  -
# 4                         Douglas C 47A FZ559  Pindi-Khut  -
#
#                                          Operator  Ground  Fatalities (air)  \
# 0              Airlines Australia GuineaTrans New       0                 8
# 1                             Airways IndiaDeccan       0                 9
# 2  (UK) Airlines International SwitzerlandInvicta       0               108
# 3                          Airlines Centrafricain       0                24
# 4                                 Force Air Royal       0                12
#
#    Aboard
# 0      11
# 1       9
# 2     145
# 3      24
# 4      12

# %%
df.describe(include="all")
# Out:
#                Year Quarter     Month          Day Country/Region  \
# count   5035.000000    5035      5035  5035.000000           4805
# unique          NaN       4        12          NaN            527
# top             NaN   Qtr 4  December          NaN         Russia
# freq            NaN    1368       497          NaN            249
# mean    1970.991063     NaN       NaN    15.785104            NaN
# std       24.814467     NaN       NaN     8.794474            NaN
# min     1908.000000     NaN       NaN     1.000000            NaN
# 25%     1951.000000     NaN       NaN     8.000000            NaN
# 50%     1970.000000     NaN       NaN    16.000000            NaN
# 75%     1992.000000     NaN       NaN    23.000000            NaN
# max     2024.000000     NaN       NaN    31.000000            NaN
#
#        Aircraft Manufacturer      Aircraft       Location  Operator  \
# count                   5035          5035           5035      4801
# unique                   633          3525           4170      2631
# top                  Douglas  Boeing B 737  Moscow Russia  Aeroflot
# freq                     994            73             16       188
# mean                     NaN           NaN            NaN       NaN
# std                      NaN           NaN            NaN       NaN
# min                      NaN           NaN            NaN       NaN
# 25%                      NaN           NaN            NaN       NaN
# 50%                      NaN           NaN            NaN       NaN
# 75%                      NaN           NaN            NaN       NaN
# max                      NaN           NaN            NaN       NaN
#
#              Ground  Fatalities (air)       Aboard
# count   5035.000000       5035.000000  5035.000000
# unique          NaN               NaN          NaN
# top             NaN               NaN          NaN
# freq            NaN               NaN          NaN
# mean       1.704469         22.218868    31.107249
# std       55.105115         34.948929    45.740185
# min        0.000000          0.000000     0.000000
# 25%        0.000000          4.000000     7.000000
# 50%        0.000000         11.000000    16.000000
# 75%        0.000000         25.000000    34.500000
# max     2750.000000        583.000000   644.000000

# %%
df.isnull().sum()
# Out:
# Year                       0
# Quarter                    0
# Month                      0
# Day                        0
# Country/Region           230
# Aircraft Manufacturer      0
# Aircraft                   0
# Location                   0
# Operator                 234
# Ground                     0
# Fatalities (air)           0
# Aboard                     0
# dtype: int64

# %%
df.isnull()
# Out:
#        Year  Quarter  Month    Day  Country/Region  Aircraft Manufacturer  \
# 0     False    False  False  False            True                  False
# 1     False    False  False  False            True                  False
# 2     False    False  False  False            True                  False
# 3     False    False  False  False           False                  False
# 4     False    False  False  False           False                  False
# ...     ...      ...    ...    ...             ...                    ...
# 5030  False    False  False  False           False                  False
# 5031  False    False  False  False           False                  False
# 5032  False    False  False  False           False                  False
# 5033  False    False  False  False           False                  False
# 5034  False    False  False  False           False                  False
#
#       Aircraft  Location  Operator  Ground  Fatalities (air)  Aboard
# 0        False     False     False   False             False   False
# 1        False     False     False   False             False   False
# 2        False     False     False   False             False   False
# 3        False     False     False   False             False   False
# 4        False     False     False   False             False   False
# ...        ...       ...       ...     ...               ...     ...
# 5030     False     False     False   False             False   False
# 5031     False     False     False   False             False   False
# 5032     False     False     False   False             False   False
# 5033     False     False     False   False             False   False
# 5034     False     False     False   False             False   False
#
# [5035 rows x 12 columns]

# %%
df["Country/Region"]= df["Country/Region"].fillna("Unknown")

# %%
df["Operator"]= df["Operator"].fillna("Unknown")

# %%
df.isnull().sum()
# Out:
# Year                     0
# Quarter                  0
# Month                    0
# Day                      0
# Country/Region           0
# Aircraft Manufacturer    0
# Aircraft                 0
# Location                 0
# Operator                 0
# Ground                   0
# Fatalities (air)         0
# Aboard                   0
# dtype: int64

# %%
df.head(10)
# Out:
#    Year Quarter  Month  Day Country/Region Aircraft Manufacturer  \
# 0  1970   Qtr 2  April   28        Unknown   de Havilland Canada
# 1  1952   Qtr 2  April   30        Unknown               Douglas
# 2  1973   Qtr 2  April   10        Unknown      Vickers Vanguard
# 3  2000   Qtr 2  April   19             '-               Antonov
# 4  1946   Qtr 2  April   30             '-               Douglas
# 5  1960   Qtr 2  April   14             '-               Douglas
# 6  2024   Qtr 2  April   23         Alaska               Douglas
# 7  1958   Qtr 2  April   21             10               Douglas
# 8  1997   Qtr 2  April   23    Afghanistan               Antonov
# 9  1988   Qtr 2  April   10    Afghanistan               Antonov
#
#                                      Aircraft  \
# 0  de Havilland Canada DHC 6 Twin Otter 100VH
# 1                              Douglas DC 3VT
# 2                  Vickers Vanguard 952G AXOP
# 3                              Antonov AN 8TL
# 4                         Douglas C 47A FZ559
# 5                               Douglas DC 4?
# 6              Douglas C-54D Skymaster N3054V
# 7                            Douglas DC 7 / F
# 8                              Antonov AN 26?
# 9                              Antonov AN 26?
#
#                           Location  \
# 0                          Kainatu
# 1                            Delhi
# 2                       Near Basel
# 3                          Pepa  -
# 4                    Pindi-Khut  -
# 5                         Taipei -
# 6                   Near Fairbanks
# 7                    Near Sloan 10
# 8          Near Konduz Afghanistan
# 9  Near Mazâr-e Charif Afghanistan
#
#                                             Operator  Ground  \
# 0                 Airlines Australia GuineaTrans New       0
# 1                                Airways IndiaDeccan       0
# 2     (UK) Airlines International SwitzerlandInvicta       0
# 3                             Airlines Centrafricain       0
# 4                                    Force Air Royal       0
# 5                               Force Air Thai Royal       0
# 6                                    Alaska Air Fuel       0
# 7  Nevada      Vegas Las of SW miles United Air L...       0
# 8             Force Air Republican Afghan - Military       0
# 9             Force Air Republican Afghan - Military       0
#
#    Fatalities (air)  Aboard
# 0                 8      11
# 1                 9       9
# 2               108     145
# 3                24      24
# 4                12      12
# 5                18      18
# 6                 2       2
# 7                49      49
# 8                36      36
# 9                29      29

# %%
#to remove rows with "'-" and "10" as the Country/Region
df = df[~df.isin(["'-"]).any(axis=1)]
df = df[~df.isin(["10"]).any(axis=1)]

# %%
df[df.duplicated()].sum()
# Out:
# Year                     0
# Quarter                  0
# Month                    0
# Day                      0
# Country/Region           0
# Aircraft Manufacturer    0
# Aircraft                 0
# Location                 0
# Operator                 0
# Ground                   0
# Fatalities (air)         0
# Aboard                   0
# dtype: object

# %%
df["Country/Region"] = df["Country/Region"].str.split('\\').str[0]

# %%
bins =[1908,1920,1932,1944,1956,1968,1980,1992,2004,2016,2024]
labels =["1908-1920","1921-1932","1933-1944","1945-1956","1957-1968","1969-1980","1981-1992","1993-2004","2005-2016","2017-2024"]

# %%
df["YearGrouped"] = pd.cut(df.Year,bins = bins,labels = labels)

# %%
df.head(15)
# Out:
#     Year Quarter  Month  Day Country/Region Aircraft Manufacturer  \
# 0   1970   Qtr 2  April   28        Unknown   de Havilland Canada
# 1   1952   Qtr 2  April   30        Unknown               Douglas
# 2   1973   Qtr 2  April   10        Unknown      Vickers Vanguard
# 6   2024   Qtr 2  April   23         Alaska               Douglas
# 8   1997   Qtr 2  April   23    Afghanistan               Antonov
# 9   1988   Qtr 2  April   10    Afghanistan               Antonov
# 10  1993   Qtr 2  April   27    Afghanistan               Antonov
# 11  2006   Qtr 2  April   24    Afghanistan               Antonov
# 12  2013   Qtr 2  April   29    Afghanistan                Boeing
# 13  1973   Qtr 2  April   18    Afghanistan   de Havilland Canada
# 14  1994   Qtr 2  April   26          Aichi                Airbus
# 15  1956   Qtr 2  April    9         Alaska        Aero Commander
# 16  1976   Qtr 2  April    5         Alaska                Boeing
# 17  1983   Qtr 2  April    7         Alaska               Britten
# 18  1964   Qtr 2  April   17         Alaska                Cessna
#
#                                       Aircraft  \
# 0   de Havilland Canada DHC 6 Twin Otter 100VH
# 1                               Douglas DC 3VT
# 2                   Vickers Vanguard 952G AXOP
# 6               Douglas C-54D Skymaster N3054V
# 8                               Antonov AN 26?
# 9                               Antonov AN 26?
# 10                              Antonov AN 32?
# 11                            Antonov AN 32BZS
# 12                                Boeing B 747
# 13  de Havilland Canada DHC 6 Twin Otter 100YA
# 14                         Airbus A300B4 622RB
# 15                   Aero Commander  520B5386N
# 16                                Boeing B 727
# 17                          Britten  Norman BN
# 18                            Cessna 185N9984X
#
#                            Location  \
# 0                           Kainatu
# 1                             Delhi
# 2                        Near Basel
# 6                    Near Fairbanks
# 8           Near Konduz Afghanistan
# 9   Near Mazâr-e Charif Afghanistan
# 10           Near Kholm Afghanistan
# 11          Lashkar Gah Afghanistan
# 12      Bagram Air Base Afghanistan
# 13              Bamiyan Afghanistan
# 14                Near Komaki Aichi
# 15               Skilak Lake Alaska
# 16                 Ketchikan Alaska
# 17                   Selawik Alaska
# 18                      Elim Alaska
#
#                                           Operator  Ground  Fatalities (air)  \
# 0               Airlines Australia GuineaTrans New       0                 8
# 1                              Airways IndiaDeccan       0                 9
# 2   (UK) Airlines International SwitzerlandInvicta       0               108
# 6                                  Alaska Air Fuel       0                 2
# 8           Force Air Republican Afghan - Military       0                36
# 9           Force Air Republican Afghan - Military       0                29
# 10          Force Air Republican Afghan - Military       0                76
# 11                        (leased) Government U.S.       3                 2
# 12                              Cargo Air National       0                 7
# 13                         Airlines Afghan Bakhtar       0                 4
# 14                   Japan China Airlines (Taiwan)       0               264
# 15                                Airlines Cordova       0                 6
# 16                                 Airlines Alaska       0                 1
# 17                          Airlines Northern Munz       0                 2
# 18                       Inc. Airlines Alaska Wein       0                 2
#
#     Aboard YearGrouped
# 0       11   1969-1980
# 1        9   1945-1956
# 2      145   1969-1980
# 6        2   2017-2024
# 8       36   1993-2004
# 9       29   1981-1992
# 10      76   1993-2004
# 11      16   2005-2016
# 12       7   2005-2016
# 13      19   1969-1980
# 14     271   1993-2004
# 15       6   1945-1956
# 16      50   1969-1980
# 17       3   1981-1992
# 18       2   1957-1968

# %%
df['Total_casualities'] = df['Fatalities (air)'] + df['Ground']

# %%
df.head(10)
# Out:
#    Year Quarter  Month  Day Country/Region Aircraft Manufacturer  \
# 0  1970   Qtr 2  April   28            NaN   de Havilland Canada
# 1  1952   Qtr 2  April   30            NaN               Douglas
# 2  1973   Qtr 2  April   10            NaN      Vickers Vanguard
# 3  2000   Qtr 2  April   19             '-               Antonov
# 4  1946   Qtr 2  April   30             '-               Douglas
# 5  1960   Qtr 2  April   14             '-               Douglas
# 6  2024   Qtr 2  April   23         Alaska               Douglas
# 7  1958   Qtr 2  April   21             10               Douglas
# 8  1997   Qtr 2  April   23    Afghanistan               Antonov
# 9  1988   Qtr 2  April   10    Afghanistan               Antonov
#
#                                      Aircraft  \
# 0  de Havilland Canada DHC 6 Twin Otter 100VH
# 1                              Douglas DC 3VT
# 2                  Vickers Vanguard 952G AXOP
# 3                              Antonov AN 8TL
# 4                         Douglas C 47A FZ559
# 5                               Douglas DC 4?
# 6              Douglas C-54D Skymaster N3054V
# 7                            Douglas DC 7 / F
# 8                              Antonov AN 26?
# 9                              Antonov AN 26?
#
#                           Location  \
# 0                          Kainatu
# 1                            Delhi
# 2                       Near Basel
# 3                          Pepa  -
# 4                    Pindi-Khut  -
# 5                         Taipei -
# 6                   Near Fairbanks
# 7                    Near Sloan 10
# 8          Near Konduz Afghanistan
# 9  Near Mazâr-e Charif Afghanistan
#
#                                             Operator  Ground  \
# 0                 Airlines Australia GuineaTrans New       0
# 1                                Airways IndiaDeccan       0
# 2     (UK) Airlines International SwitzerlandInvicta       0
# 3                             Airlines Centrafricain       0
# 4                                    Force Air Royal       0
# 5                               Force Air Thai Royal       0
# 6                                    Alaska Air Fuel       0
# 7  Nevada      Vegas Las of SW miles United Air L...       0
# 8             Force Air Republican Afghan - Military       0
# 9             Force Air Republican Afghan - Military       0
#
#    Fatalities (air)  Aboard  total_casualities  Total_casualities
# 0                 8      11                  8                  8
# 1                 9       9                  9                  9
# 2               108     145                108                108
# 3                24      24                 24                 24
# 4                12      12                 12                 12
# 5                18      18                 18                 18
# 6                 2       2                  2                  2
# 7                49      49                 49                 49
# 8                36      36                 36                 36
# 9                29      29                 29                 29

# %% [markdown]
# # Research Questions
# 1. What is the total number of aircrashes, fatalities, aboard, ground, and survivors across the dataset?
# 2. what is the Deadliest Location in terms of casualities?
# 3. What is the Country with the most crashes?
# 4. Which Aircraft has been involved the most with crashes?
# 5. Which Aircraft Manufacturer has the most crashes?
# 6. What is the trend in aircrashes over the years in terms of casialities?
# 7. What Month had the most crashes?
# 8. Which Airline Operator has the most number of crashes?
